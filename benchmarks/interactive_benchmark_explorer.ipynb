# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib widget

# %%
from interactive_benchmark_plot_selector import launch_selector, load_history

# %%
df = load_history("results/benchmark_history.parquet")
ui = launch_selector(df)
