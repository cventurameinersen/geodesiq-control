# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geodesiq._utils import Flags

# %%
flags = Flags()
flags.add('A', value=True)
flags.add('B', parent='A', value=True)
flags.add('C', parent='B', value=True)

flags
# Out:
# Flags(
#   A: stored=True,
#   B: stored=True, parents=['A']
#   C: stored=True, parents=['B']
# )

# %%
flags['A'] = False
flags
# Out:
# Flags(
#   A: stored=False,
#   B: stored=False, parents=['A']
#   C: stored=False, parents=['B']
# )
