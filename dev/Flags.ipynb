# %%
# %load_ext autoreload
# %autoreload 2

# %%
from geodesiq.utils import Flags

# %%
flags = Flags()
flags.add('A', value=True)
flags.add('B', parent='A', value=True)
flags.add('C', parent='B', value=True)

flags
# Out:
# Flags(
#   A: stored=True,
#   B: stored=True, parent='A'
#   C: stored=True, parent='B'
# )

# %%
flags['A'] = False
flags
# Out:
# Flags(
#   A: stored=False,
#   B: stored=False, parent='A'
#   C: stored=False, parent='B'
# )
